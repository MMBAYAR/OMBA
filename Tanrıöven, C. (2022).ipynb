# %% [markdown]
# <a href="https://colab.research.google.com/github/MMBAYAR/OMBA/blob/main/Tanr%C4%B1%C3%B6ven%2C%20C.%20(2022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/drive')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.cluster import KMeans
import tensorflow as tf

plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = [9,7]
plt.rcParams['figure.dpi'] = 300
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

# !python -m pip install gurobipy

# from gurobipy import*

# # Create environment with WLS license
# e = Env(empty=True)
# e.setParam('WLSACCESSID', '1291b2f8-8ffe-422d-aaf0-1e1cd54b5e36')
# e.setParam('WLSSECRET', 'baa1f76c-8b87-40fc-90e0-89cff99a3ea4')
# e.setParam('LICENSEID',793542)
# e.start()
# Out:
# Mounted at /drive

# %%
df = pd.read_excel('/drive/MyDrive/iibf/iibf_tüm_dersler.xlsx')
df.fillna('Yönetim Bilişim Sistemleri')
df
# Out:
#         Dkod                                         Dadı  \
# 0    EKON103                                  MATEMATİK I
# 1    IKTI101                             İKTİSADA GİRİŞ I
# 2    IKTI107                             İKTİSAT TARİHİ I
# 3    ING-101                                  İNGİLİZCE-I
# 4    ISLE103                       İŞLETME BİLİMİNE GİRİŞ
# ..       ...                                          ...
# 740  ISLE428               SOSYAL MEDYA PAZARLAMASI (SEÇ)
# 741   YBS408                   GENETİK ALGORİTMALAR (SEÇ)
# 742   YBS410               COĞRAFİ BİLGİ SİSTEMLERİ (SEÇ)
# 743   YBS412                      DİJİTAL PAZARLAMA (SEÇ)
# 744   YBS414  FİNANSAL TEKNOLOJİLER VE UYGULAMALARI (SEÇ)
#
#                            Dböl
# 0                       İktisat
# 1                       İktisat
# 2                       İktisat
# 3                       İktisat
# 4                       İktisat
# ..                          ...
# 740  Yönetim Bilişim Sistemleri
# ...

# %%
df[ ['MATEMATİ' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                           Dadı  \
# 611  EKON105                      MATEMATİK
# 687  EKON105                      MATEMATİK
# 470  EKON105                      MATEMATİK
# 234  EKON103                    MATEMATİK I
# 317  EKON103                    MATEMATİK I
# 0    EKON103                    MATEMATİK I
# 243  EKON104                   MATEMATİK II
# 8    EKON104                   MATEMATİK II
# 329  EKON104             MATEMATİK II (SEÇ)
# 20   IKTI207   MATEMATİKSEL İKTİSAT I (SEÇ)
# 29   IKTI208  MATEMATİKSEL İKTİSAT II (SEÇ)
# 707  EKON319          İLERİ MATEMATİK (SEÇ)
# 542  ISLE122             İŞLETME MATEMATİĞİ
# 82   ISLE122             İŞLETME MATEMATİĞİ
#
#                                          Dböl
# 611                      Uluslararası Ticaret
# 687                Yönetim Bilişim Sistemleri
# 470  Çalışma Ekonomisi ve Endüstri İlişkileri
# 234                                Ekonometri
# 317                                    Maliye
# ...

# %%
df[ ['İSTATİSTİK' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                       Dadı  \
# 572  EKON108                             BİYOİSTATİSTİK
# 295  EKON415            PARAMETRE DIŞI İSTATİSTİK (SEÇ)
# 281  EKON312  ÇOK DEĞİŞKENLİ İSTATİSTİKSEL ANALİZ (SEÇ)
# 563  EKON107                                 İSTATİSTİK
# 628  EKON107                                 İSTATİSTİK
# 688  EKON107                                 İSTATİSTİK
# 76   EKON107                                 İSTATİSTİK
# 225  ECON107                           İSTATİSTİK (SEÇ)
# 479  EKON107              İSTATİSTİK VE OLASILIĞA GİRİŞ
# 233  EKON101            İSTATİSTİK VE OLASILIĞA GİRİŞ I
# 326  EKON101            İSTATİSTİK VE OLASILIĞA GİRİŞ I
# 17   EKON101            İSTATİSTİK VE OLASILIĞA GİRİŞ I
# 242  EKON102           İSTATİSTİK VE OLASILIĞA GİRİŞ II
# 26   EKON102           İSTATİSTİK VE OLASILIĞA GİRİŞ II
# 338  EKON102     İSTATİSTİK VE OLASILIĞA GİRİŞ II (SEÇ)
# 250  EKON201                       İSTATİSTİKİ ANALİZ I
# ...

# %%
df[ ['HUKU' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                Dadı  \
# 313  KAMU103                      ANAYASA HUKUKU
# 158  KAMU103                      ANAYASA HUKUKU
# 411  KAMU103                      ANAYASA HUKUKU
# 474  KAMU103                      ANAYASA HUKUKU
# 256  KAMU103                ANAYASA HUKUKU (SEÇ)
# ..       ...                                 ...
# 559  KAMU207                  İDARE HUKUKU (SEÇ)
# 425  KAMU207                  İDARE HUKUKU (SEÇ)
# 504  KAMU207                  İDARE HUKUKU (SEÇ)
# 195  CALI301                     İŞ HUKUKU (SEÇ)
# 575  CALI313  İŞ VE SOSYAL GÜVENLİK HUKUKU (SEÇ)
#
#                                          Dböl
# 313                                    Maliye
# 158           Siyaset Bilimi ve Kamu Yönetimi
# 411                    Uluslararası İlişkiler
# 474  Çalışma Ekonomisi ve Endüstri İlişkileri
# 256                                Ekonometri
# ..                                        ...
# ...

# %%
df[ ['MUHASEBE' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                             Dadı  \
# 678  UTIC406              DIŞ TİCARET İŞLEMLERİ VE MUHASEBESİ
# 95   ISLE207                 DÖNEM SONU MUHASEBE UYGULAMALARI
# 699  ISLE107                                FİNANSAL MUHASEBE
# 81   ISLE107                              FİNANSAL MUHASEBE I
# 88   ISLE106                             FİNANSAL MUHASEBE II
# 186  ISLE114                             GENEL MUHASEBE (SEÇ)
# 433  ISLE114                             GENEL MUHASEBE (SEÇ)
# 340  ISLE307                         MALİYET MUHASEBESİ (SEÇ)
# 642  ISLE307                         MALİYET MUHASEBESİ (SEÇ)
# 523  ISLE307                         MALİYET MUHASEBESİ (SEÇ)
# 112  ISLE303                             MALİYET MUHASEBESİ I
# 129  ISLE318                      MALİYET MUHASEBESİ II (SEÇ)
# 143  ISLE406                                MUHASEBE DENETİMİ
# 661  ISLE406                          MUHASEBE DENETİMİ (SEÇ)
# ...

# %%
df[ ['FİNANS' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                               Dadı  \
# 639  UTIC202                             DIŞ TİCARET FİNANSMANI
# 291  EKON407                          FİNANSAL EKONOMETRİ (SEÇ)
# 72   IKTI416  FİNANSAL GLOBALLEŞME VE GELİŞEN PİYASA EKONOM3ERİ
# 699  ISLE107                                  FİNANSAL MUHASEBE
# 81   ISLE107                                FİNANSAL MUHASEBE I
# 88   ISLE106                               FİNANSAL MUHASEBE II
# 358  IKTI210                           FİNANSAL PİYASALAR (SEÇ)
# 512  IKTI210                           FİNANSAL PİYASALAR (SEÇ)
# 30   IKTI210                           FİNANSAL PİYASALAR (SEÇ)
# 123  ISLE405                          FİNANSAL TABLOLAR ANALİZİ
# 633  ISLE405                    FİNANSAL TABLOLAR ANALİZİ (SEÇ)
# 716  ISLE405                    FİNANSAL TABLOLAR ANALİZİ (SEÇ)
# 536  ISLE405                    FİNANSAL TABLOLAR ANALİZİ (SEÇ)
# 744   YBS414        FİNANSAL TEKNOLOJİLER VE UYGULAMALARI (SEÇ)
# ...

# %%
df[ ['PAZARLAMA' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                  Dadı                        Dböl
# 652  ISLE419  BÜTÜNLEŞİK PAZARLAMA İLETİŞİMİ (SEÇ)        Uluslararası Ticaret
# 139  ISLE419  BÜTÜNLEŞİK PAZARLAMA İLETİŞİMİ (SEÇ)                     İşletme
# 148  ISLE416              DOĞRUDAN PAZARLAMA (SEÇ)                     İşletme
# 743   YBS412               DİJİTAL PAZARLAMA (SEÇ)  Yönetim Bilişim Sistemleri
# 640  ISLE220           ENDÜSTRİYEL PAZARLAMA (SEÇ)        Uluslararası Ticaret
# 662  ISLE411              HİZMET PAZARLAMASI (SEÇ)        Uluslararası Ticaret
# 140  ISLE451              HİZMET PAZARLAMASI (SEÇ)                     İşletme
# 670  ISLE315           PAZARLAMA ARAŞTIRMASI (SEÇ)        Uluslararası Ticaret
# 117  ISLE315           PAZARLAMA ARAŞTIRMASI (SEÇ)                     İşletme
# 122  ISLE306                PAZARLAMA STRATEJİLERİ                     İşletme
# 638  ISLE208                    PAZARLAMA YÖNETİMİ        Uluslararası Ticaret
# ...

# %%
df[ ['ÜRETİM' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                         Dadı  \
# 116  ISLE313               MODERN ÜRETİM SİSTEMLERİ (SEÇ)
# 557  ISLE217  SAĞLIK İŞLETMELERİNDE ÜRETİM YÖNETİMİ (SEÇ)
# 720   YBS311        ÇOKLU ORTAM TASARIMI VE ÜRETİMİ (SEÇ)
# 137  ISLE415            ÜRETİM PLANLAMA VE DENETİMİ (SEÇ)
# 647  ISLE329                              ÜRETİM YÖNETİMİ
# 710   YBS209                        ÜRETİM YÖNETİMİ (SEÇ)
# 104  ISLE210                   ÜRETİM İŞLEMLER YÖNETİMİ I
# 113  ISLE305                  ÜRETİM İŞLEMLER YÖNETİMİ II
#
#                            Dböl
# 116                     İşletme
# 557             Sağlık Yönetimi
# 720  Yönetim Bilişim Sistemleri
# 137                     İşletme
# 647        Uluslararası Ticaret
# 710  Yönetim Bilişim Sistemleri
# 104                     İşletme
# 113                     İşletme

# %%
df[ ['İNGİLİZ' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                   Dadı                                      Dböl
# 421  ULUS305    MESLEKİ İNGİLİZCE I                    Uluslararası İlişkiler
# 431  ULUS306   MESLEKİ İNGİLİZCE II                    Uluslararası İlişkiler
# 440  ULUS401  MESLEKİ İNGİLİZCE III                    Uluslararası İlişkiler
# 452  ULUS406   MESLEKİ İNGİLİZCE IV                    Uluslararası İlişkiler
# 154   ING103            İNGİLİZCE I           Siyaset Bilimi ve Kamu Yönetimi
# 164   ING104           İNGİLİZCE II           Siyaset Bilimi ve Kamu Yönetimi
# 237  ING-101            İNGİLİZCE-I                                Ekonometri
# 310  ING-101            İNGİLİZCE-I                                    Maliye
# 539  ING-101            İNGİLİZCE-I                           Sağlık Yönetimi
# 613  ING-101            İNGİLİZCE-I                      Uluslararası Ticaret
# 386  ING-101            İNGİLİZCE-I                    Uluslararası İlişkiler
# ...

# %%
df[ ['EKONO' in df['Dadı'][i] for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                               Dadı  \
# 513  IKTI322       BÜYÜME TEORİLERİ VE KALKINMA EKONOMİSİ (SEÇ)
# 300  EKON406                   BİLGİSAYAR UYGULAMALI EKONOMETRİ
# 378  IKTI311           DOĞAL KAYNAKLAR VE ÇEVRE EKONOMİSİ (SEÇ)
# 41   IKTI311           DOĞAL KAYNAKLAR VE ÇEVRE EKONOMİSİ (SEÇ)
# 60   IKTI411   DÜNYA EKONOMİSİ VE KÜRESEL EKONOMİ POLİTİK (SE3)
# 368  MALI409          DÜZENLEMELER VE ANTİTRÖST EKONOMİSİ (SEÇ)
# 344  EKON304                                         EKONOMETRİ
# 492  EKON304                                   EKONOMETRİ (SEÇ)
# 268  EKON301                                       EKONOMETRİ I
# 35   EKON301                                       EKONOMETRİ I
# 278  EKON302                                      EKONOMETRİ II
# 45   EKON302                                      EKONOMETRİ II
# 283  EKON316                         EKONOMİK GÖSTERGELER (SEÇ)
# 679  IKTI312                             ENERJİ EKONOMİSİ (SEÇ)
# ...

# %%
df[ [('SAYISAL' in df['Dadı'][i] or 'YÖNEYLEM' in df['Dadı'][i] or 'OPTİMİZASY' in df['Dadı'][i]) for i in range(len(df))] ].sort_values(['Dadı','Dböl'])
# Out:
#         Dkod                                           Dadı  \
# 576  ISLE325  SAĞLIK İŞLETMELERİNDE SAYISAL YÖNTEMLER (SEÇ)
# 289  EKON403                UYGULAMALI YÖNEYLEM ARAŞTIRMASI
# 641  ISLE224                     YÖNEYLEM ARAŞTIRMASI (SEÇ)
# 724  EKON305                     YÖNEYLEM ARAŞTIRMASI (SEÇ)
# 270  EKON305                         YÖNEYLEM ARAŞTIRMASI I
# 133  ISLE403                         YÖNEYLEM ARAŞTIRMASI I
# 279  EKON306                        YÖNEYLEM ARAŞTIRMASI II
# 149  ISLE418                  YÖNEYLEM ARAŞTIRMASI II (SEÇ)
#
#                            Dböl
# 576             Sağlık Yönetimi
# 289                  Ekonometri
# 641        Uluslararası Ticaret
# 724  Yönetim Bilişim Sistemleri
# 270                  Ekonometri
# 133                     İşletme
# 279                  Ekonometri
# 149                     İşletme
